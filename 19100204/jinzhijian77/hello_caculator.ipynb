# %%
2 + 2  #addition
# Out:
# 4

# %%
8 - 5  #subtraction
# Out:
# 3

# %%
5 * 7  #multiplication
# Out:
# 35

# %%
30 / 6  #division always returns a floating point number
# Out:
# 5.0

# %%
5 ** 2  #squared
# Out:
# 25
